# %% [markdown]
# ### Chapter 5, Section 3: The Fundamental Theorem of Calculus
#
# - This section connects derivatives to integrals (e.g. Antiderivatives).
# - Problems: Paper (3, 5, 9, 11, 15, 19, 21, 23, 25, 33, 35, 43, 47, 51 ).

# %% [markdown]
# ![alt text](../../Downloads/1000015063.jpg)

# %% [markdown]
# ![alt text](1000015063.jpg)

# %% [markdown]
# ![alt text](1000015283.jpg)
